# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pyopenspecy
from importlib.resources import files
import pandas as pd
import matplotlib.pyplot as plt

# %%
m = pyopenspecy.random_raman_metadata()
m
# Out:
# {'sample_name': 3809,
#  'spectrum_identity': 'Hauyne',
#  'spectrum_id': 'Hauyne__R070557-3__Raman__514__0__ccw__Raman_Data_Processed__24726',
#  'other_information': 'rruff.info/R070557'}

# %%
s, meta = pyopenspecy.random_raman_spectrum()
plt.plot(s.wavenumber, s.intensity, '-', 'k')
plt.xlabel("Raman Shift (cm$^{-1}$)")
plt.ylabel("Intensity")
plt.title(meta["spectrum_identity"])
plt.show()

# %%
m = pyopenspecy.random_ftir_metadata()
m
# Out:
# {'sample_name': 330,
#  'spectrum_identity': 'sealing ring Gardena 2824 medium',
#  'spectrum_id': '58Primpke',
#  'other_information': 'Natural /Synthetic Plastic/other rubber sealing_ring_Gardena_2824_medium'}

# %%
s, meta = pyopenspecy.random_ftir_spectrum()
print(s.head(10))
plt.plot(s.wavenumber, s.intensity, '-', 'k')
plt.xlabel("Wavenumber")
plt.ylabel("Intensity")
plt.title(meta["spectrum_identity"])
plt.show()
# Out:
#         wavenumber  intensity  sample_name  group
# 353757      3992.6   0.002254          431    431
# 354079      3990.7   0.002538          431    431
# 354401      3988.8   0.002870          431    431
# 354723      3986.8   0.003194          431    431
# 355045      3984.9   0.003483          431    431
# 355367      3983.0   0.003779          431    431
# 355689      3981.1   0.004074          431    431
# 356011      3979.1   0.004272          431    431
# 356333      3977.2   0.004370          431    431
# 356655      3975.3   0.004553          431    431

# %%
pyopenspecy.raman_spectrum_by_id(700)
# Out:
#         wavenumber  intensity  sample_name  group
# 126782       109.0   0.038543          700    700
# 126783       109.5   0.052656          700    700
# 126784       110.0   0.047710          700    700
# 126785       110.5   0.039050          700    700
# 126786       111.0   0.033837          700    700
# ...            ...        ...          ...    ...
# 129215      1282.0   0.000000          700    700
# 129216      1282.5   0.000000          700    700
# 129217      1283.0   0.000000          700    700
# 129218      1283.5   0.000000          700    700
# 129219      1284.0   0.000000          700    700
#
# [2438 rows x 4 columns]
